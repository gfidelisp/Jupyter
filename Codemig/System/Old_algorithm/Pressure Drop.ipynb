# %%
import matplotlib.pyplot as plt
from scipy import *
import numpy as np
from matplotlib import *
rc('text',usetex = True)
rc('font', family='serif',size = 12)

# %%
Re_e  = [4.390233821,8.767310099,13.50402591,17.88548804,22.60466046,27.13524141,33.07806542,36.69200415,42.91990827]
Erg = [131.9562082,69.92808204,48.1054935,38.21054429,31.8436795,27.81483243,24.20341539,22.57925911,20.42215918]
Exp = [405.4173127,260.9893462,192.4130878,163.944966,145.4268407,133.3682528,113.7854047,117.7562159,99.88849472]
Re = np.arange(4,45)

# %%
plt.plot(Re_e,Exp,'o',label = 'Bez')
plt.plot(Re_e,Erg,'s',label = 'Erg')
plt.plot(Re,957.58*Re**-0.601,'--', label = '$aRe^b$')
plt.plot(Re,419.03*Re**-0.817,'--', label = '$cRe^d$')
plt.xlabel('Re$_\mathrm{dp}$ [-]')
plt.ylabel('f$_D$ [-]' )
plt.grid()
plt.legend()
plt.savefig('fD.png',format = 'png', dpi=500,bbox_inches='tight')
